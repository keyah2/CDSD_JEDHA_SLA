# %% [markdown]
# # Analyse du dataset **Speed Dating**
# ### Jedha — Bloc 2
#
# **Question métier.**
# Quels facteurs augmentent la probabilité qu'un speed date débouche sur une **décision positive** (`dec`) puis sur un **match mutuel** (`match`) ?

# %%
import warnings
warnings.filterwarnings("ignore")

# --- Librairies standard ---
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

# --- Scikit-learn : modélisation (bonus) ---
from sklearn.model_selection import GroupShuffleSplit
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score
from sklearn.inspection import permutation_importance

# Afficher toutes les colonnes sans troncature
pd.set_option("display.max_columns", 200)
pd.set_option("display.width", 160)


def find_file(candidates):
    """Cherche un fichier parmi plusieurs noms possibles dans les répertoires courants du projet."""
    cwd = Path.cwd()
    # Liste des dossiers où le fichier peut se trouver selon l'environnement d'exécution
    search_roots = [
        cwd,
        cwd / "data",
        cwd / "notebooks",
        cwd.parent,
        cwd.parent / "data",
        Path("/mnt/data"),
        Path("/mnt/data/speed-dating-tinder-analysis/data"),
    ]
    for root in search_roots:
        for name in candidates:
            p = root / name
            if p.exists():
                return p
    raise FileNotFoundError(f"Impossible de trouver un fichier parmi : {candidates}")


# Chargement des chemins vers les fichiers de données
DATA_PATH = find_file([
    "speed_dating_data.csv",
    "Speed+Dating+Data (1).csv",
    "Speed+Dating+Data.csv",
])
KEY_PATH = find_file([
    "speed_dating_data_key.doc",
    "Speed+Dating+Data+Key.doc",
    "Speed+Dating+Data+Key (1).doc",
])

print("Dataset trouvé :", DATA_PATH)
print("Data key trouvé :", KEY_PATH)

# %% [markdown]
# ## 1. Chargement des données et compréhension de la structure
#
# **Point méthodologique clé.**
# Chaque ligne correspond à la **perception d'un participant pour un rendez-vous donné**.
# Un même speed date apparaît donc généralement **deux fois** dans la table :
# - une fois du point de vue de la personne A ;
# - une fois du point de vue de la personne B.
#
# Cette particularité n'est pas un problème, mais elle doit être explicitée avant toute lecture des KPI.

# %%
# Lecture du CSV (encodage latin1 requis pour ce dataset)
df = pd.read_csv(DATA_PATH, encoding="latin1")
print("Shape :", df.shape)
display(df.head(3))

# Reconstruction des paires uniques de speed dates
# Chaque rendez-vous apparaît deux fois dans le dataset (une ligne par participant)
# On construit un identifiant de paire unique : wave_min(iid,pid)_max(iid,pid)
tmp = df[['wave', 'iid', 'pid', 'match']].dropna(subset=['pid']).copy()
tmp['pair_id'] = tmp.apply(
    lambda r: f"{int(r.wave)}_{min(int(r.iid), int(r.pid))}_{max(int(r.iid), int(r.pid))}",
    axis=1
)
pair_df = tmp.drop_duplicates('pair_id')

# Résumé des statistiques clés du dataset
summary_df = pd.DataFrame({
    "metric": [
        "Lignes dans le dataset",
        "Speed dates uniques (niveau paire)",
        "Participants uniques",
        "Nombre de vagues",
        "Taux de match (niveau ligne)",
        "Taux de décision positive - dec (niveau ligne)"
    ],
    "value": [
        len(df),
        len(pair_df),
        df['iid'].nunique(),
        df['wave'].nunique(),
        round(df['match'].mean() * 100, 2),
        round(df['dec'].mean() * 100, 2),
    ]
})
display(summary_df)
# Out:
# Shape : (8378, 195)
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  pf_o_sin  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4        1  11.0      0      0.14         0   27.0     2.0      35.0      20.0
# 1    1  1.0       0    1       1     1     10         7       NaN      3        2  12.0      0      0.54         0   22.0     2.0      60.0       0.0
# 2    1  1.0       0    1       1     1     10         7       NaN     10        3  13.0      1      0.16         1   22.0     4.0      19.0      18.0
#
#    pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  intel_o  fun_o  amb_o  shar_o  like_o  prob_o  met_o   age field  field_cd undergra mn_sat  \
# 0      20.0      20.0       0.0       5.0      0     6.0     8.0      8.0    8.0    8.0     6.0     7.0     4.0    2.0  21.0   Law       1.0      NaN    NaN
# 1       0.0      40.0       0.0       0.0      0     7.0     8.0     10.0    7.0    7.0     5.0     8.0     4.0    2.0  21.0   Law       1.0      NaN    NaN
# 2      19.0      18.0      14.0      12.0      1    10.0    10.0     10.0   10.0   10.0    10.0    10.0    10.0    1.0  21.0   Law       1.0      NaN    NaN
#
#   tuition  race  imprace  imprelig     from zipcode     income  goal  date  go_out  career  career_c  sports  tvsports  exercise  dining  museums  art  \
# 0     NaN   4.0      2.0       4.0  Chicago  60,521  69,487.00   2.0   7.0     1.0  lawyer       NaN     9.0       2.0       8.0     9.0      1.0  1.0
# 1     NaN   4.0      2.0       4.0  Chicago  60,521  69,487.00   2.0   7.0     1.0  lawyer       NaN     9.0       2.0       8.0     9.0      1.0  1.0
# 2     NaN   4.0      2.0       4.0  Chicago  60,521  69,487.00   2.0   7.0     1.0  lawyer       NaN     9.0       2.0       8.0     9.0      1.0  1.0
#
#    hiking  gaming  clubbing  reading   tv  theater  movies  concerts  music  shopping  yoga  exphappy  expnum  attr1_1  sinc1_1  intel1_1  fun1_1  amb1_1  \
# 0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0       3.0     2.0     15.0     20.0      20.0    15.0    15.0
# 1     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0       3.0     2.0     15.0     20.0      20.0    15.0    15.0
# 2     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0       3.0     2.0     15.0     20.0      20.0    15.0    15.0
#
#    shar1_1  attr4_1  sinc4_1  intel4_1  fun4_1  amb4_1  shar4_1  attr2_1  sinc2_1  intel2_1  fun2_1  amb2_1  shar2_1  attr3_1  sinc3_1  fun3_1  intel3_1  \
# 0     15.0      NaN      NaN       NaN     NaN     NaN      NaN     35.0     20.0      15.0    20.0     5.0      5.0      6.0      8.0     8.0       8.0
# 1     15.0      NaN      NaN       NaN     NaN     NaN      NaN     35.0     20.0      15.0    20.0     5.0      5.0      6.0      8.0     8.0       8.0
# 2     15.0      NaN      NaN       NaN     NaN     NaN      NaN     35.0     20.0      15.0    20.0     5.0      5.0      6.0      8.0     8.0       8.0
#
#    amb3_1  attr5_1  sinc5_1  intel5_1  fun5_1  amb5_1  dec  attr  sinc  intel  fun  amb  shar  like  prob  met  match_es  attr1_s  sinc1_s  intel1_s  fun1_s  \
# 0     7.0      NaN      NaN       NaN     NaN     NaN    1   6.0   9.0    7.0  7.0  6.0   5.0   7.0   6.0  2.0       4.0      NaN      NaN       NaN     NaN
# 1     7.0      NaN      NaN       NaN     NaN     NaN    1   7.0   8.0    7.0  8.0  5.0   6.0   7.0   5.0  1.0       4.0      NaN      NaN       NaN     NaN
# 2     7.0      NaN      NaN       NaN     NaN     NaN    1   5.0   8.0    9.0  8.0  5.0   7.0   7.0   NaN  1.0       4.0      NaN      NaN       NaN     NaN
#
#    amb1_s  shar1_s  attr3_s  sinc3_s  intel3_s  fun3_s  amb3_s  satis_2  length  numdat_2  attr7_2  sinc7_2  intel7_2  fun7_2  amb7_2  shar7_2  attr1_2  \
# 0     NaN      NaN      NaN      NaN       NaN     NaN     NaN      6.0     2.0       1.0      NaN      NaN       NaN     NaN     NaN      NaN    19.44
# 1     NaN      NaN      NaN      NaN       NaN     NaN     NaN      6.0     2.0       1.0      NaN      NaN       NaN     NaN     NaN      NaN    19.44
# 2     NaN      NaN      NaN      NaN       NaN     NaN     NaN      6.0     2.0       1.0      NaN      NaN       NaN     NaN     NaN      NaN    19.44
#
#    sinc1_2  intel1_2  fun1_2  amb1_2  shar1_2  attr4_2  sinc4_2  intel4_2  fun4_2  amb4_2  shar4_2  attr2_2  sinc2_2  intel2_2  fun2_2  amb2_2  shar2_2  \
# 0    16.67     13.89   22.22   11.11    16.67      NaN      NaN       NaN     NaN     NaN      NaN      NaN      NaN       NaN     NaN     NaN      NaN
# 1    16.67     13.89   22.22   11.11    16.67      NaN      NaN       NaN     NaN     NaN      NaN      NaN      NaN       NaN     NaN     NaN      NaN
# 2    16.67     13.89   22.22   11.11    16.67      NaN      NaN       NaN     NaN     NaN      NaN      NaN      NaN       NaN     NaN     NaN      NaN
#
#    attr3_2  sinc3_2  intel3_2  fun3_2  amb3_2  attr5_2  sinc5_2  intel5_2  fun5_2  amb5_2  you_call  them_cal  date_3  numdat_3  num_in_3  attr1_3  sinc1_3  \
# 0      6.0      7.0       8.0     7.0     6.0      NaN      NaN       NaN     NaN     NaN       1.0       1.0     0.0       NaN       NaN     15.0     20.0
# 1      6.0      7.0       8.0     7.0     6.0      NaN      NaN       NaN     NaN     NaN       1.0       1.0     0.0       NaN       NaN     15.0     20.0
# 2      6.0      7.0       8.0     7.0     6.0      NaN      NaN       NaN     NaN     NaN       1.0       1.0     0.0       NaN       NaN     15.0     20.0
#
#    intel1_3  fun1_3  amb1_3  shar1_3  attr7_3  sinc7_3  intel7_3  fun7_3  amb7_3  shar7_3  attr4_3  sinc4_3  intel4_3  fun4_3  amb4_3  shar4_3  attr2_3  \
# 0      20.0    15.0    15.0     15.0      NaN      NaN       NaN     NaN     NaN      NaN      NaN      NaN       NaN     NaN     NaN      NaN      NaN
# 1      20.0    15.0    15.0     15.0      NaN      NaN       NaN     NaN     NaN      NaN      NaN      NaN       NaN     NaN     NaN      NaN      NaN
# 2      20.0    15.0    15.0     15.0      NaN      NaN       NaN     NaN     NaN      NaN      NaN      NaN       NaN     NaN     NaN      NaN      NaN
#
#    sinc2_3  intel2_3  fun2_3  amb2_3  shar2_3  attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  fun5_3  amb5_3
# 0      NaN       NaN     NaN     NaN      NaN      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN     NaN     NaN
# 1      NaN       NaN     NaN     NaN      NaN      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN     NaN     NaN
# 2      NaN       NaN     NaN     NaN      NaN      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN     NaN     NaN
#                                            metric    value
# 0                          Lignes dans le dataset  8378.00
# 1              Speed dates uniques (niveau paire)  4184.00
# 2                            Participants uniques   551.00
# 3                                Nombre de vagues    21.00
# 4                    Taux de match (niveau ligne)    16.47
# 5  Taux de décision positive - dec (niveau ligne)    41.99

# %% [markdown]
# ## 1.1. Bien définir l'unité d'analyse
#
# Le dataset peut être lu à **trois niveaux complémentaires** :
#
# - **niveau ligne** : la perception d'un participant pour un rendez-vous précis ;
# - **niveau participant** : ses taux moyens, ses attentes et son auto-évaluation ;
# - **niveau paire** : le rendez-vous réel entre deux personnes.
#
# Cette distinction conditionne la bonne interprétation de `dec` et `match`.

# %%
# Copie de travail pour éviter de modifier le dataframe original
work = df.copy()

# Création d'un identifiant de paire reproductible (min/max pour éviter les doublons d'ordre)
work['pair_low'] = work[['iid', 'pid']].min(axis=1)
work['pair_high'] = work[['iid', 'pid']].max(axis=1)

# Calcul de l'écart d'âge absolu entre les deux participants
work['age_gap'] = (work['age'] - work['age_o']).abs()

# Agrégation au niveau paire : une ligne = un speed date réel entre deux personnes
pair_df = (
    work.groupby(['wave', 'pair_low', 'pair_high'])
        .agg(
            match=('match', 'first'),         # le match est identique pour les deux lignes
            samerace=('samerace', 'first'),    # idem
            shar_pair=('shar', 'mean'),        # moyenne des deux perceptions
            attr_pair=('attr', 'mean'),
            fun_pair=('fun', 'mean'),
            like_pair=('like', 'mean'),
            age_gap=('age_gap', 'mean')
        )
        .reset_index()
)

# Tableau récapitulatif des trois niveaux d'analyse possibles
analysis_levels = pd.DataFrame({
    'Niveau': ['Ligne (perception individuelle)', 'Participant', 'Paire (date réel)'],
    'Volume': [len(df), df['iid'].nunique(), len(pair_df)],
    'Exemple de variable cible': ['dec', 'taux moyen de match', 'match'],
    'Lecture': [
        'Une personne évalue un date',
        'On résume le comportement dun individu sur toute la soirée',
        'On observe un rendez-vous unique entre deux personnes'
    ]
})

display(analysis_levels)
print("Taux de match au niveau ligne :", f"{df['match'].mean():.2%}")
print("Taux de match au niveau paire :", f"{pair_df['match'].mean():.2%}")
# Out:
#                             Niveau  Volume Exemple de variable cible                                            Lecture
# 0  Ligne (perception individuelle)    8378                       dec                        Une personne évalue un date
# 1                      Participant     551       taux moyen de match  On résume le comportement dun individu sur tou...
# 2                Paire (date réel)    4194                     match  On observe un rendez-vous unique entre deux pe...
# Taux de match au niveau ligne : 16.47%
# Taux de match au niveau paire : 16.45%

# %% [markdown]
# ### Pourquoi cette distinction est utile
#
# - `dec` se lit naturellement au **niveau ligne**, car il s'agit d'une décision individuelle ;
# - `match` peut être lu au **niveau ligne** pour les KPI globaux, mais aussi au **niveau paire** pour certains contrôles de robustesse ;
# - raisonner explicitement sur ces niveaux évite de surinterpréter des résultats produits sur des observations dupliquées par construction.

# %% [markdown]
# ## 2. Qualité des données
#
# Avant de commenter les résultats, on vérifie :
# - la structure générale du dataset ;
# - les types de variables ;
# - les valeurs manquantes ;
# - les doublons exacts ;
# - la disponibilité réelle des colonnes utiles pour chaque question du brief.
#
# L'objectif n'est pas de forcer un nettoyage artificiel, mais de documenter clairement ce qui est exploitable et ce qui ne l'est pas.

# %%
# Aperçu général des types et volumes de données
display(df.info())

# Calcul du nombre de valeurs manquantes par colonne, trié par ordre décroissant
na_counts = df.isna().sum().sort_values(ascending=False)

# Vérification des doublons exacts (même ligne répétée)
dupes = df.duplicated().sum()
print("Nombre de doublons exacts :", dupes)

# Visualisation : top 20 des colonnes avec le plus de valeurs manquantes
na_top20 = na_counts.head(20).sort_values(ascending=True)

plt.figure(figsize=(8, 6))
plt.barh(na_top20.index, na_top20.values)
plt.title("Top 20 des colonnes les plus manquantes")
plt.xlabel("Nombre de valeurs manquantes")
plt.ylabel("Colonnes")
plt.tight_layout()
plt.show()

# Tableau des valeurs manquantes pour référence
display(na_counts.head(20).to_frame("valeurs_manquantes"))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), str(8)
# memory usage: 12.5 MB
# None
# Nombre de doublons exacts : 0
#           valeurs_manquantes
# num_in_3                7710
# numdat_3                6882
# expnum                  6578
# sinc7_2                 6423
# amb7_2                  6423
# shar7_2                 6404
# attr7_2                 6394
# fun7_2                  6394
# intel7_2                6394
# fun5_3                  6362
# amb5_3                  6362
# shar2_3                 6362
# attr5_3                 6362
# amb7_3                  6362
# shar7_3                 6362
# sinc5_3                 6362
# sinc7_3                 6362
# intel7_3                6362
# fun7_3                  6362
# attr7_3                 6362

# %% [markdown]
# ## 3. Définir correctement les deux cibles : `dec` et `match`
#
# Deux variables jouent un rôle central dans le projet :
#
# - **`dec`** : le participant souhaite revoir la personne ;
# - **`match`** : les deux participants souhaitent se revoir.
#
# Dans une logique produit, `dec` mesure un **intérêt individuel**, tandis que `match` mesure la **réciprocité**.
# La distinction est essentielle : un bon yes rate individuel ne garantit pas un bon taux de match.

# %%
# Calcul du yes rate et du match rate par genre
# gender : 0 = femmes, 1 = hommes
gender_summary = (
    df.groupby('gender')
      .agg(
          n=('match', 'size'),
          yes_rate=('dec', 'mean'),       # proportion de décisions positives
          match_rate=('match', 'mean'),   # proportion de matches mutuels
          age_mean=('age', 'mean')
      )
      .rename(index={0: 'Femmes', 1: 'Hommes'})
)

display(gender_summary.style.format({
    'yes_rate': '{:.2%}',
    'match_rate': '{:.2%}',
    'age_mean': '{:.2f}'
}))

# Graphique comparatif yes rate vs match rate par genre
plot_df = gender_summary[['yes_rate', 'match_rate']].copy() * 100
x = np.arange(len(plot_df.index))
width = 0.35

plt.figure(figsize=(7, 4))
plt.bar(x - width / 2, plot_df['yes_rate'], width, label='Yes rate (dec)')
plt.bar(x + width / 2, plot_df['match_rate'], width, label='Match rate')
plt.xticks(x, plot_df.index)
plt.ylabel("Pourcentage")
plt.title("Décision positive et match mutuel par genre")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5c0ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c0ed_level0_col0" class="col_heading level0 col0" >n</th>
#       <th id="T_5c0ed_level0_col1" class="col_heading level0 col1" >yes_rate</th>
#       <th id="T_5c0ed_level0_col2" class="col_heading level0 col2" >match_rate</th>
#       <th id="T_5c0ed_level0_col3" class="col_heading level0 col3" >age_mean</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c0ed_level0_row0" class="row_heading level0 row0" >Femmes</th>
#       <td id="T_5c0ed_row0_col0" class="data row0 col0" >4184</td>
#       <td id="T_5c0ed_row0_col1" class="data row0 col1" >36.54%</td>
#       <td id="T_5c0ed_row0_col2" class="data row0 col2" >16.49%</td>
#       <td id="T_5c0ed_row0_col3" class="data row0 col3" >26.11</td>
#     </tr>
#     <tr>
#       <th id="T_5c0ed_level0_row1" class="row_heading level0 row1" >Hommes</th>
#       <td id="T_5c0ed_row1_col0" class="data row1 col0" >4194</td>
#       <td id="T_5c0ed_row1_col1" class="data row1 col1" >47.42%</td>
#       <td id="T_5c0ed_row1_col2" class="data row1 col2" >16.45%</td>
#       <td id="T_5c0ed_row1_col3" class="data row1 col3" >26.61</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Première lecture des KPI
#
# Le tableau et le graphique ci-dessous permettent de comparer les décisions positives et les matches selon le genre.
#
# Le point important à observer est le suivant :
# - le comportement de réponse individuelle peut différer fortement ;
# - mais le résultat final réciproque peut rester proche.

# %% [markdown]
# ## 3.1. Vérification de robustesse au niveau participant
#
# Comme un même participant apparaît plusieurs fois dans le dataset, il est utile de compléter la lecture ligne par ligne par une lecture **par participant**.
#
# On calcule donc, pour chaque individu :
# - son **yes rate moyen** ;
# - son **match rate moyen** ;
# - puis on compare la distribution de ces taux selon le genre.

# %%
# Calcul des taux moyens par participant (niveau iid, pas par ligne)
# Chaque participant peut apparaître N fois → on résume son comportement global
participant_rates = (
    df.groupby(['iid', 'gender'])
      .agg(
          yes_rate=('dec', 'mean'),
          match_rate=('match', 'mean'),
          n_dates=('dec', 'size')
      )
      .reset_index()
)

# Calcul des intervalles de confiance à 95% pour chaque métrique et chaque genre
rows = []
for metric in ['yes_rate', 'match_rate']:
    for g, label in [(0, 'Femmes'), (1, 'Hommes')]:
        x = participant_rates.loc[participant_rates['gender'] == g, metric].dropna()
        mean = x.mean()
        se = x.std(ddof=1) / np.sqrt(len(x))   # erreur standard
        rows.append({
            'Métrique': metric,
            'Genre': label,
            'Moyenne': mean,
            'IC95 bas': mean - 1.96 * se,
            'IC95 haut': mean + 1.96 * se,
            'n participants': len(x)
        })

participant_ci = pd.DataFrame(rows)
display(participant_ci.style.format({
    'Moyenne': '{:.2%}',
    'IC95 bas': '{:.2%}',
    'IC95 haut': '{:.2%}'
}))

# Graphiques avec barres d'erreur (intervalles de confiance)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
for ax, metric, title in zip(
    axes,
    ['yes_rate', 'match_rate'],
    ['Yes rate moyen par participant', 'Match rate moyen par participant']
):
    sub = participant_ci[participant_ci['Métrique'] == metric].copy()
    ax.bar(sub['Genre'], sub['Moyenne'] * 100)
    ax.errorbar(
        sub['Genre'], sub['Moyenne'] * 100,
        yerr=[(sub['Moyenne'] - sub['IC95 bas']) * 100, (sub['IC95 haut'] - sub['Moyenne']) * 100],
        fmt='none', capsize=5
    )
    ax.set_ylabel("Pourcentage")
    ax.set_title(title)
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_53e7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53e7c_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_53e7c_level0_col1" class="col_heading level0 col1" >Genre</th>
#       <th id="T_53e7c_level0_col2" class="col_heading level0 col2" >Moyenne</th>
#       <th id="T_53e7c_level0_col3" class="col_heading level0 col3" >IC95 bas</th>
#       <th id="T_53e7c_level0_col4" class="col_heading level0 col4" >IC95 haut</th>
#       <th id="T_53e7c_level0_col5" class="col_heading level0 col5" >n participants</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53e7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53e7c_row0_col0" class="data row0 col0" >yes_rate</td>
#       <td id="T_53e7c_row0_col1" class="data row0 col1" >Femmes</td>
#       <td id="T_53e7c_row0_col2" class="data row0 col2" >37.38%</td>
#       <td id="T_53e7c_row0_col3" class="data row0 col3" >34.54%</td>
#       <td id="T_53e7c_row0_col4" class="data row0 col4" >40.22%</td>
#       <td id="T_53e7c_row0_col5" class="data row0 col5" >274</td>
#     </tr>
#     <tr>
#       <th id="T_53e7c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_53e7c_row1_col0" class="data row1 col0" >yes_rate</td>
#       <td id="T_53e7c_row1_col1" class="data row1 col1" >Hommes</td>
#       <td id="T_53e7c_row1_col2" class="data row1 col2" >48.11%</td>
#       <td id="T_53e7c_row1_col3" class="data row1 col3" >45.04%</td>
#       <td id="T_53e7c_row1_col4" class="data row1 col4" >51.18%</td>
#       <td id="T_53e7c_row1_col5" class="data row1 col5" >277</td>
#     </tr>
#     <tr>
#       <th id="T_53e7c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_53e7c_row2_col0" class="data row2 col0" >match_rate</td>
#       <td id="T_53e7c_row2_col1" class="data row2 col1" >Femmes</td>
#       <td id="T_53e7c_row2_col2" class="data row2 col2" >16.87%</td>
#       <td id="T_53e7c_row2_col3" class="data row2 col3" >15.09%</td>
#       <td id="T_53e7c_row2_col4" class="data row2 col4" >18.64%</td>
#       <td id="T_53e7c_row2_col5" class="data row2 col5" >274</td>
#     </tr>
#     <tr>
#       <th id="T_53e7c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_53e7c_row3_col0" class="data row3 col0" >match_rate</td>
#       <td id="T_53e7c_row3_col1" class="data row3 col1" >Hommes</td>
#       <td id="T_53e7c_row3_col2" class="data row3 col2" >16.92%</td>
#       <td id="T_53e7c_row3_col3" class="data row3 col3" >15.15%</td>
#       <td id="T_53e7c_row3_col4" class="data row3 col4" >18.69%</td>
#       <td id="T_53e7c_row3_col5" class="data row3 col5" >277</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Interprétation
#
# Cette vérification vise à s'assurer que le message observé plus haut ne vient pas simplement du fait qu'une même personne apparaît de nombreuses fois dans la base.
#
# Si la lecture par participant confirme la lecture par ligne, l'interprétation devient plus robuste.

# %% [markdown]
# ## 3.2. Synthèse exécutive des premiers enseignements
#
# À ce stade, trois idées structurantes se dégagent déjà :
#
# 1. le **match mutuel** reste relativement rare ;
# 2. les hommes ont tendance à dire **oui** plus souvent ;
# 3. cette différence de yes rate ne se convertit pas mécaniquement en davantage de matches mutuels.
#
# Autrement dit, la variable décisive n'est pas seulement l'intensité de l'intérêt individuel, mais la **réciprocité**.

# %%
# Corrélations des principales variables d'interaction avec le match
# (sélection des variables les plus représentatives)
top_corr = (
    df[['match', 'attr', 'fun', 'shar', 'like']]
      .corr(numeric_only=True)['match']
      .drop('match')
      .sort_values(ascending=False)
)

# Tableau de synthèse des KPI globaux
kpis = pd.DataFrame({
    'KPI': [
        'Taux de décision positive (dec)',
        'Taux de match mutuel',
        'Yes rate — hommes',
        'Yes rate — femmes',
        'Match rate — hommes',
        'Match rate — femmes'
    ],
    'Valeur': [
        df['dec'].mean(),
        df['match'].mean(),
        df.loc[df['gender'] == 1, 'dec'].mean(),
        df.loc[df['gender'] == 0, 'dec'].mean(),
        df.loc[df['gender'] == 1, 'match'].mean(),
        df.loc[df['gender'] == 0, 'match'].mean(),
    ]
})

display(kpis.style.format({'Valeur': '{:.2%}'}))
display(top_corr.rename('Corrélation avec match').to_frame().style.format('{:.3f}'))
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0252">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0252_level0_col0" class="col_heading level0 col0" >KPI</th>
#       <th id="T_e0252_level0_col1" class="col_heading level0 col1" >Valeur</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0252_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0252_row0_col0" class="data row0 col0" >Taux de décision positive (dec)</td>
#       <td id="T_e0252_row0_col1" class="data row0 col1" >41.99%</td>
#     </tr>
#     <tr>
#       <th id="T_e0252_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0252_row1_col0" class="data row1 col0" >Taux de match mutuel</td>
#       <td id="T_e0252_row1_col1" class="data row1 col1" >16.47%</td>
#     </tr>
#     <tr>
#       <th id="T_e0252_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0252_row2_col0" class="data row2 col0" >Yes rate — hommes</td>
#       <td id="T_e0252_row2_col1" class="data row2 col1" >47.42%</td>
#     </tr>
#     <tr>
#       <th id="T_e0252_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0252_row3_col0" class="data row3 col0" >Yes rate — femmes</td>
#       <td id="T_e0252_row3_col1" class="data row3 col1" >36.54%</td>
#     </tr>
#     <tr>
#       <th id="T_e0252_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0252_row4_col0" class="data row4 col0" >Match rate — hommes</td>
#       <td id="T_e0252_row4_col1" class="data row4 col1" >16.45%</td>
#     </tr>
#     <tr>
#       <th id="T_e0252_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0252_row5_col0" class="data row5 col0" >Match rate — femmes</td>
#       <td id="T_e0252_row5_col1" class="data row5 col1" >16.49%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_70c1f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70c1f_level0_col0" class="col_heading level0 col0" >Corrélation avec match</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70c1f_level0_row0" class="row_heading level0 row0" >like</th>
#       <td id="T_70c1f_row0_col0" class="data row0 col0" >0.306</td>
#     </tr>
#     <tr>
#       <th id="T_70c1f_level0_row1" class="row_heading level0 row1" >fun</th>
#       <td id="T_70c1f_row1_col0" class="data row1 col0" >0.278</td>
#     </tr>
#     <tr>
#       <th id="T_70c1f_level0_row2" class="row_heading level0 row2" >shar</th>
#       <td id="T_70c1f_row2_col0" class="data row2 col0" >0.271</td>
#     </tr>
#     <tr>
#       <th id="T_70c1f_level0_row3" class="row_heading level0 row3" >attr</th>
#       <td id="T_70c1f_row3_col0" class="data row3 col0" >0.261</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. Variables observées pendant l'interaction et issue du rendez-vous
#
# On examine maintenant les notes attribuées **pendant ou juste après le date** :
# - `attr` : attractiveness
# - `sinc` : sincerity
# - `intel` : intelligence
# - `fun` : fun
# - `amb` : ambition
# - `shar` : shared interests
# - `like` : appréciation globale
# - `prob` : probabilité perçue que l'autre réponde oui
#
# Ces variables sont très informatives pour **décrire la mécanique d'un rendez-vous réussi**.
# En revanche, elles ne doivent pas être confondues avec des variables disponibles **avant** la rencontre.

# %%
# Variables observées pendant ou juste après le rendez-vous
rating_cols = ['attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob']

# Moyenne de chaque note selon l'issue (match ou non)
mean_by_match = (
    df.groupby('match')[rating_cols]
      .mean()
      .T
      .rename(columns={0: 'Pas de match', 1: 'Match'})
)

# Corrélation de chaque note avec dec (décision individuelle) et match (réciprocité)
corr_match = df[rating_cols + ['match']].corr(numeric_only=True)['match'].drop('match').sort_values(ascending=False)
corr_dec   = df[rating_cols + ['dec']].corr(numeric_only=True)['dec'].drop('dec').sort_values(ascending=False)

display(mean_by_match)
display(pd.DataFrame({
    'corr_avec_dec': corr_dec,
    'corr_avec_match': corr_match
}).sort_values('corr_avec_match', ascending=False))

# Graphique : corrélation de chaque attribut avec le match
plt.figure(figsize=(8, 4))
plt.bar(corr_match.index, corr_match.values)
plt.title("Corrélation des notes du date avec le match")
plt.ylabel("Corrélation")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# match  Pas de match     Match
# attr       5.961230  7.319535
# sinc       7.046056  7.809489
# intel      7.249851  7.950365
# fun        6.155185  7.598535
# amb        6.663891  7.332949
# shar       5.208230  6.753571
# like       5.880169  7.381904
# prob       4.961883  6.412884
#        corr_avec_dec  corr_avec_match
# like        0.513463         0.305723
# fun         0.414477         0.277545
# shar        0.400644         0.270679
# attr        0.486775         0.260676
# prob        0.310861         0.255531
# intel       0.217313         0.169532
# sinc        0.209994         0.164449
# amb         0.183659         0.140042

# %% [markdown]
# ### Principaux constats
#
# Le lecteur doit surtout comparer :
# - les écarts de moyennes entre `match=0` et `match=1` ;
# - les corrélations avec `dec` et `match`.
#
# L'objectif n'est pas de conclure à une causalité stricte, mais d'identifier les signaux les plus associés à une issue positive.

# %% [markdown]
# ## 5. Préférences déclarées avant l'événement : quelles qualités sont les moins valorisées ?
#
# Le brief invite à comparer les qualités recherchées par les participants et à vérifier si cette hiérarchie diffère selon le genre.
#
# ### Point de méthode
# Les vagues du dataset n'utilisent pas toutes la même échelle :
# - certaines reposent sur une allocation de **100 points** ;
# - d'autres sur une échelle **1–10**.
#
# Pour rendre la comparaison cohérente, on travaille donc en **poids relatifs** au sein de chaque répondant.

# %%
# Colonnes des préférences déclarées AVANT l'événement (vague 1)
pref_cols = ['attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1']
pref_labels = {
    'attr1_1': 'Attractiveness',
    'sinc1_1': 'Sincérité',
    'intel1_1': 'Intelligence',
    'fun1_1': 'Fun',
    'amb1_1': 'Ambition',
    'shar1_1': 'Intérêts partagés'
}

pref_work = df[['gender'] + pref_cols].copy()

# Normalisation en poids relatif (%) pour rendre comparables les différentes échelles de notation
# Certaines vagues utilisent 100 points à distribuer, d'autres une échelle 1-10
pref_sum = pref_work[pref_cols].sum(axis=1)
for c in pref_cols:
    pref_work[c + '_share'] = np.where(pref_sum > 0, pref_work[c] / pref_sum * 100, np.nan)

# Moyenne des poids relatifs par genre
pref_share_gender = (
    pref_work.groupby('gender')[[c + '_share' for c in pref_cols]]
             .mean()
             .rename(index={0: 'Femmes évaluant des hommes', 1: 'Hommes évaluant des femmes'})
             .T
)
pref_share_gender.index = [pref_labels[c.replace('_share', '')] for c in pref_share_gender.index]

display(pref_share_gender.style.format('{:.2f}%'))

# Graphique en barres groupées
plot_df = pref_share_gender.copy()
x = np.arange(len(plot_df.index))
width = 0.35

plt.figure(figsize=(9, 5))
plt.bar(x - width / 2, plot_df.iloc[:, 0], width, label=plot_df.columns[0])
plt.bar(x + width / 2, plot_df.iloc[:, 1], width, label=plot_df.columns[1])
plt.xticks(x, plot_df.index, rotation=45, ha='right')
plt.ylabel("Poids moyen normalisé (%)")
plt.title("Préférences déclarées avant le speed dating")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b01f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th id="T_7b01f_level0_col0" class="col_heading level0 col0" >Femmes évaluant des hommes</th>
#       <th id="T_7b01f_level0_col1" class="col_heading level0 col1" >Hommes évaluant des femmes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b01f_level0_row0" class="row_heading level0 row0" >Attractiveness</th>
#       <td id="T_7b01f_row0_col0" class="data row0 col0" >18.06%</td>
#       <td id="T_7b01f_row0_col1" class="data row0 col1" >26.91%</td>
#     </tr>
#     <tr>
#       <th id="T_7b01f_level0_row1" class="row_heading level0 row1" >Sincérité</th>
#       <td id="T_7b01f_row1_col0" class="data row1 col0" >18.31%</td>
#       <td id="T_7b01f_row1_col1" class="data row1 col1" >16.48%</td>
#     </tr>
#     <tr>
#       <th id="T_7b01f_level0_row2" class="row_heading level0 row2" >Intelligence</th>
#       <td id="T_7b01f_row2_col0" class="data row2 col0" >21.01%</td>
#       <td id="T_7b01f_row2_col1" class="data row2 col1" >19.52%</td>
#     </tr>
#     <tr>
#       <th id="T_7b01f_level0_row3" class="row_heading level0 row3" >Fun</th>
#       <td id="T_7b01f_row3_col0" class="data row3 col0" >17.15%</td>
#       <td id="T_7b01f_row3_col1" class="data row3 col1" >17.75%</td>
#     </tr>
#     <tr>
#       <th id="T_7b01f_level0_row4" class="row_heading level0 row4" >Ambition</th>
#       <td id="T_7b01f_row4_col0" class="data row4 col0" >12.83%</td>
#       <td id="T_7b01f_row4_col1" class="data row4 col1" >8.50%</td>
#     </tr>
#     <tr>
#       <th id="T_7b01f_level0_row5" class="row_heading level0 row5" >Intérêts partagés</th>
#       <td id="T_7b01f_row5_col0" class="data row5 col0" >12.71%</td>
#       <td id="T_7b01f_row5_col1" class="data row5 col1" >10.97%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Interprétation
#
# L'enjeu n'est pas seulement de classer les qualités, mais de repérer celles qui arrivent **systématiquement en bas de hiérarchie**.
#
# Cela permet de répondre proprement à la question du brief sans mélanger des échelles de réponse hétérogènes.

# %% [markdown]
# ## 6. *Attractiveness* : importance déclarée, importance reconstruite et impact observé
#
# L'attractivité est l'une des questions centrales du sujet.
# On l'aborde sous trois angles complémentaires :
#
# 1. **avant l'événement** : ce que les participants disent rechercher ;
# 2. **après l'événement** : ce qu'ils déclarent avoir réellement pris en compte ;
# 3. **dans les données observées** : ce qui est le plus associé à `dec`.
#
# Cette comparaison permet d'opposer **discours déclaré** et **comportement observé**.

# %%
# Colonnes des préférences APRÈS l'événement (réévaluation a posteriori)
post_cols = ['attr7_2', 'sinc7_2', 'intel7_2', 'fun7_2', 'amb7_2', 'shar7_2']
post_labels = {
    'attr7_2': 'Attractiveness',
    'sinc7_2': 'Sincérité',
    'intel7_2': 'Intelligence',
    'fun7_2': 'Fun',
    'amb7_2': 'Ambition',
    'shar7_2': 'Intérêts partagés'
}

# Même normalisation en poids relatif que pour les préférences déclarées avant
post_work = df[['gender'] + post_cols].copy()
post_sum = post_work[post_cols].sum(axis=1)
for c in post_cols:
    post_work[c + '_share'] = np.where(post_sum > 0, post_work[c] / post_sum * 100, np.nan)

post_share_gender = (
    post_work.groupby('gender')[[c + '_share' for c in post_cols]]
             .mean()
             .rename(index={0: 'Femmes', 1: 'Hommes'})
             .T
)
post_share_gender.index = [post_labels[c.replace('_share', '')] for c in post_share_gender.index]

# Impact observé : corrélation de chaque attribut avec la décision (dec), par genre
obs_rows = []
for g in [0, 1]:
    sub = df[df['gender'] == g]
    for feat in ['attr', 'sinc', 'intel', 'fun', 'amb', 'shar']:
        temp = sub[[feat, 'dec']].dropna()
        obs_rows.append({
            'genre': 'Femmes' if g == 0 else 'Hommes',
            'attribut': feat,
            'corr_avec_dec': temp[feat].corr(temp['dec'])
        })

obs_impact = pd.DataFrame(obs_rows)
obs_pivot = (
    obs_impact
    .pivot(index='attribut', columns='genre', values='corr_avec_dec')
    .loc[['attr', 'sinc', 'intel', 'fun', 'amb', 'shar']]
)
obs_pivot.index = ['Attractiveness', 'Sincérité', 'Intelligence', 'Fun', 'Ambition', 'Intérêts partagés']

display(post_share_gender.style.format('{:.2f}%'))
display(obs_pivot.style.format('{:.3f}'))

# Graphique : impact observé (corrélation avec dec) par genre
plot_df = obs_pivot.copy()
x = np.arange(len(plot_df.index))
width = 0.35

plt.figure(figsize=(9, 5))
plt.bar(x - width / 2, plot_df['Femmes'], width, label='Femmes')
plt.bar(x + width / 2, plot_df['Hommes'], width, label='Hommes')
plt.xticks(x, plot_df.index, rotation=45, ha='right')
plt.ylabel("Corrélation avec la décision 'oui'")
plt.title("Impact observé des attributs sur la décision individuelle")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5753f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >gender</th>
#       <th id="T_5753f_level0_col0" class="col_heading level0 col0" >Femmes</th>
#       <th id="T_5753f_level0_col1" class="col_heading level0 col1" >Hommes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5753f_level0_row0" class="row_heading level0 row0" >Attractiveness</th>
#       <td id="T_5753f_row0_col0" class="data row0 col0" >29.15%</td>
#       <td id="T_5753f_row0_col1" class="data row0 col1" >37.41%</td>
#     </tr>
#     <tr>
#       <th id="T_5753f_level0_row1" class="row_heading level0 row1" >Sincérité</th>
#       <td id="T_5753f_row1_col0" class="data row1 col0" >15.37%</td>
#       <td id="T_5753f_row1_col1" class="data row1 col1" >11.71%</td>
#     </tr>
#     <tr>
#       <th id="T_5753f_level0_row2" class="row_heading level0 row2" >Intelligence</th>
#       <td id="T_5753f_row2_col0" class="data row2 col0" >15.54%</td>
#       <td id="T_5753f_row2_col1" class="data row2 col1" >14.99%</td>
#     </tr>
#     <tr>
#       <th id="T_5753f_level0_row3" class="row_heading level0 row3" >Fun</th>
#       <td id="T_5753f_row3_col0" class="data row3 col0" >18.40%</td>
#       <td id="T_5753f_row3_col1" class="data row3 col1" >19.39%</td>
#     </tr>
#     <tr>
#       <th id="T_5753f_level0_row4" class="row_heading level0 row4" >Ambition</th>
#       <td id="T_5753f_row4_col0" class="data row4 col0" >8.19%</td>
#       <td id="T_5753f_row4_col1" class="data row4 col1" >6.39%</td>
#     </tr>
#     <tr>
#       <th id="T_5753f_level0_row5" class="row_heading level0 row5" >Intérêts partagés</th>
#       <td id="T_5753f_row5_col0" class="data row5 col0" >13.79%</td>
#       <td id="T_5753f_row5_col1" class="data row5 col1" >10.40%</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4315b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th id="T_4315b_level0_col0" class="col_heading level0 col0" >Femmes</th>
#       <th id="T_4315b_level0_col1" class="col_heading level0 col1" >Hommes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4315b_level0_row0" class="row_heading level0 row0" >Attractiveness</th>
#       <td id="T_4315b_row0_col0" class="data row0 col0" >0.445</td>
#       <td id="T_4315b_row0_col1" class="data row0 col1" >0.515</td>
#     </tr>
#     <tr>
#       <th id="T_4315b_level0_row1" class="row_heading level0 row1" >Sincérité</th>
#       <td id="T_4315b_row1_col0" class="data row1 col0" >0.222</td>
#       <td id="T_4315b_row1_col1" class="data row1 col1" >0.191</td>
#     </tr>
#     <tr>
#       <th id="T_4315b_level0_row2" class="row_heading level0 row2" >Intelligence</th>
#       <td id="T_4315b_row2_col0" class="data row2 col0" >0.233</td>
#       <td id="T_4315b_row2_col1" class="data row2 col1" >0.217</td>
#     </tr>
#     <tr>
#       <th id="T_4315b_level0_row3" class="row_heading level0 row3" >Fun</th>
#       <td id="T_4315b_row3_col0" class="data row3 col0" >0.417</td>
#       <td id="T_4315b_row3_col1" class="data row3 col1" >0.407</td>
#     </tr>
#     <tr>
#       <th id="T_4315b_level0_row4" class="row_heading level0 row4" >Ambition</th>
#       <td id="T_4315b_row4_col0" class="data row4 col0" >0.175</td>
#       <td id="T_4315b_row4_col1" class="data row4 col1" >0.220</td>
#     </tr>
#     <tr>
#       <th id="T_4315b_level0_row5" class="row_heading level0 row5" >Intérêts partagés</th>
#       <td id="T_4315b_row5_col0" class="data row5 col0" >0.413</td>
#       <td id="T_4315b_row5_col1" class="data row5 col1" >0.387</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Message principal
#
# Le bon message n'est pas : *« tout se résume au physique »*.
#
# Le bon message est plus nuancé :
# - l'attractivité joue un rôle important ;
# - mais elle est concurrencée par des dimensions relationnelles comme le **fun** et les **intérêts partagés** ;
# - elle doit donc être lue comme un levier fort, mais **non exclusif**.

# %% [markdown]
# ## 7. Intérêts partagés ou proximité démographique ?
#
# Cette section répond à une autre question importante du brief :
# les **intérêts partagés** comptent-ils davantage que la simple similarité démographique ?
#
# On compare ici :
# - `samerace` : une proximité démographique binaire ;
# - `shar` : une compatibilité perçue pendant l'échange.
#
# La comparaison est précieuse dans une logique produit, car elle oppose un signal **statique** à un signal **relationnel**.

# %%
# --- Signal 1 : samerace (similarité démographique binaire) ---
same_race_summary = (
    df.groupby('samerace')
      .agg(
          yes_rate=('dec', 'mean'),
          match_rate=('match', 'mean'),
          n=('match', 'size')
      )
      .rename(index={0: 'Race différente', 1: 'Même race'})
)

# --- Signal 2 : shar (intérêts partagés perçus pendant le date) ---
# Découpage en 4 bins pour observer le gradient de match
shar_tmp = df[['shar', 'dec', 'match']].dropna().copy()
shar_tmp['shar_bin'] = pd.cut(shar_tmp['shar'], bins=[0, 3, 5, 7, 10], include_lowest=True)
shar_summary = shar_tmp.groupby('shar_bin', observed=False).agg(
    yes_rate=('dec', 'mean'),
    match_rate=('match', 'mean'),
    n=('match', 'size')
)

# Calcul du lift relatif pour comparer l'amplitude des deux effets
race_lift = (
    same_race_summary.loc['Même race', 'match_rate'] /
    same_race_summary.loc['Race différente', 'match_rate'] - 1
)
shar_lift = shar_summary['match_rate'].iloc[-1] / shar_summary['match_rate'].iloc[0] - 1

# Tableau comparatif des deux signaux
effet_comparaison = pd.DataFrame({
    'Signal': ['Même race', 'Intérêts partagés : très haut vs très bas'],
    'Match rate référence': [
        same_race_summary.loc['Race différente', 'match_rate'],
        shar_summary['match_rate'].iloc[0]
    ],
    'Match rate exposé': [
        same_race_summary.loc['Même race', 'match_rate'],
        shar_summary['match_rate'].iloc[-1]
    ],
    'Lift relatif': [race_lift, shar_lift]
})

display(same_race_summary.style.format({'yes_rate': '{:.2%}', 'match_rate': '{:.2%}'}))
display(shar_summary.style.format({'yes_rate': '{:.2%}', 'match_rate': '{:.2%}'}))
display(effet_comparaison.style.format({
    'Match rate référence': '{:.2%}',
    'Match rate exposé': '{:.2%}',
    'Lift relatif': '{:+.1%}'
}))

# Graphiques de comparaison
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].bar(['Race différente', 'Même race'], same_race_summary['match_rate'] * 100)
axes[0].set_ylabel("Taux de match (%)")
axes[0].set_title("Effet du fait d'être de la même race")

axes[1].bar(shar_summary.index.astype(str), shar_summary['match_rate'] * 100)
axes[1].set_ylabel("Taux de match (%)")
axes[1].set_xlabel("Niveau d'intérêts partagés")
axes[1].set_title("Effet des intérêts partagés sur le match")
axes[1].tick_params(axis='x', rotation=15)

plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9af93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9af93_level0_col0" class="col_heading level0 col0" >yes_rate</th>
#       <th id="T_9af93_level0_col1" class="col_heading level0 col1" >match_rate</th>
#       <th id="T_9af93_level0_col2" class="col_heading level0 col2" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >samerace</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9af93_level0_row0" class="row_heading level0 row0" >Race différente</th>
#       <td id="T_9af93_row0_col0" class="data row0 col0" >41.07%</td>
#       <td id="T_9af93_row0_col1" class="data row0 col1" >16.08%</td>
#       <td id="T_9af93_row0_col2" class="data row0 col2" >5062</td>
#     </tr>
#     <tr>
#       <th id="T_9af93_level0_row1" class="row_heading level0 row1" >Même race</th>
#       <td id="T_9af93_row1_col0" class="data row1 col0" >43.40%</td>
#       <td id="T_9af93_row1_col1" class="data row1 col1" >17.07%</td>
#       <td id="T_9af93_row1_col2" class="data row1 col2" >3316</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0daab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0daab_level0_col0" class="col_heading level0 col0" >yes_rate</th>
#       <th id="T_0daab_level0_col1" class="col_heading level0 col1" >match_rate</th>
#       <th id="T_0daab_level0_col2" class="col_heading level0 col2" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shar_bin</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0daab_level0_row0" class="row_heading level0 row0" >(-0.001, 3.0]</th>
#       <td id="T_0daab_row0_col0" class="data row0 col0" >13.71%</td>
#       <td id="T_0daab_row0_col1" class="data row0 col1" >4.89%</td>
#       <td id="T_0daab_row0_col2" class="data row0 col2" >1371</td>
#     </tr>
#     <tr>
#       <th id="T_0daab_level0_row1" class="row_heading level0 row1" >(3.0, 5.0]</th>
#       <td id="T_0daab_row1_col0" class="data row1 col0" >33.67%</td>
#       <td id="T_0daab_row1_col1" class="data row1 col1" >9.83%</td>
#       <td id="T_0daab_row1_col2" class="data row1 col2" >2248</td>
#     </tr>
#     <tr>
#       <th id="T_0daab_level0_row2" class="row_heading level0 row2" >(5.0, 7.0]</th>
#       <td id="T_0daab_row2_col0" class="data row2 col0" >54.06%</td>
#       <td id="T_0daab_row2_col1" class="data row2 col1" >22.07%</td>
#       <td id="T_0daab_row2_col2" class="data row2 col2" >2401</td>
#     </tr>
#     <tr>
#       <th id="T_0daab_level0_row3" class="row_heading level0 row3" >(7.0, 10.0]</th>
#       <td id="T_0daab_row3_col0" class="data row3 col0" >71.57%</td>
#       <td id="T_0daab_row3_col1" class="data row3 col1" >34.24%</td>
#       <td id="T_0daab_row3_col2" class="data row3 col2" >1291</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_2ce5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ce5e_level0_col0" class="col_heading level0 col0" >Signal</th>
#       <th id="T_2ce5e_level0_col1" class="col_heading level0 col1" >Match rate référence</th>
#       <th id="T_2ce5e_level0_col2" class="col_heading level0 col2" >Match rate exposé</th>
#       <th id="T_2ce5e_level0_col3" class="col_heading level0 col3" >Lift relatif</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ce5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ce5e_row0_col0" class="data row0 col0" >Même race</td>
#       <td id="T_2ce5e_row0_col1" class="data row0 col1" >16.08%</td>
#       <td id="T_2ce5e_row0_col2" class="data row0 col2" >17.07%</td>
#       <td id="T_2ce5e_row0_col3" class="data row0 col3" >+6.1%</td>
#     </tr>
#     <tr>
#       <th id="T_2ce5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ce5e_row1_col0" class="data row1 col0" >Intérêts partagés : très haut vs très bas</td>
#       <td id="T_2ce5e_row1_col1" class="data row1 col1" >4.89%</td>
#       <td id="T_2ce5e_row1_col2" class="data row1 col2" >34.24%</td>
#       <td id="T_2ce5e_row1_col3" class="data row1 col3" >+600.6%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Lecture des résultats
#
# Il faut surtout observer l'ampleur relative des effets :
#
# - si `samerace` fait peu bouger le taux de match, son utilité produit est probablement limitée ;
# - si `shar` crée un gradient fort, alors la compatibilité vécue pendant l'échange est un signal beaucoup plus puissant.

# %% [markdown]
# ## 7.1. Vérification supplémentaire au niveau paire
#
# Pour renforcer l'analyse, on passe du niveau ligne au **niveau paire** et on pose deux questions :
#
# 1. l'effet de `samerace` reste-t-il visible quand le niveau de `shared interests` est comparable ?
# 2. comment évolue le match quand l'attractivité moyenne du duo et les intérêts partagés moyens augmentent ensemble ?
#
# Cette lecture évite de s'en tenir à une comparaison trop brute.

# %%
# Analyse au niveau paire pour vérifier la robustesse des résultats précédents
pair_interest = pair_df[['match', 'samerace', 'shar_pair', 'attr_pair']].dropna().copy()

# Découpage en bandes pour croiser les deux signaux
pair_interest['shar_band'] = pd.cut(
    pair_interest['shar_pair'],
    bins=[0, 3, 5, 7, 10],
    include_lowest=True,
    labels=['Très bas', 'Bas-moyen', 'Moyen-haut', 'Très haut']
)
pair_interest['attr_band'] = pd.cut(
    pair_interest['attr_pair'],
    bins=[0, 4, 6, 8, 10],
    include_lowest=True,
    labels=['Faible', 'Moyenne', 'Haute', 'Très haute']
)

# Effet de samerace à niveau d'intérêts partagés comparable
# Si l'effet disparaît à shar contrôlé, c'est que shar est le vrai signal
race_within_shar = (
    pair_interest.groupby(['shar_band', 'samerace'], observed=False)
                 .agg(match_rate=('match', 'mean'), n=('match', 'size'))
                 .reset_index()
)
display(race_within_shar.style.format({'match_rate': '{:.2%}'}))

# Heatmap : taux de match selon l'attractivité moyenne ET les intérêts partagés du duo
heat = pair_interest.pivot_table(
    index='shar_band',
    columns='attr_band',
    values='match',
    aggfunc='mean'
)

fig, ax = plt.subplots(figsize=(7, 4.5))
im = ax.imshow(heat.values, aspect='auto')
ax.set_xticks(range(len(heat.columns)))
ax.set_xticklabels(heat.columns)
ax.set_yticks(range(len(heat.index)))
ax.set_yticklabels(heat.index)
ax.set_xlabel("Attractiveness moyenne du duo")
ax.set_ylabel("Intérêts partagés moyens du duo")
ax.set_title("Taux de match au niveau paire")

# Affichage des valeurs dans chaque case
for i in range(heat.shape[0]):
    for j in range(heat.shape[1]):
        val = heat.iloc[i, j]
        if pd.notna(val):
            ax.text(j, i, f"{val:.0%}", ha='center', va='center', color='white')

plt.colorbar(im, ax=ax, label='Taux de match')
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_a453d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a453d_level0_col0" class="col_heading level0 col0" >shar_band</th>
#       <th id="T_a453d_level0_col1" class="col_heading level0 col1" >samerace</th>
#       <th id="T_a453d_level0_col2" class="col_heading level0 col2" >match_rate</th>
#       <th id="T_a453d_level0_col3" class="col_heading level0 col3" >n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a453d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a453d_row0_col0" class="data row0 col0" >Très bas</td>
#       <td id="T_a453d_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_a453d_row0_col2" class="data row0 col2" >2.72%</td>
#       <td id="T_a453d_row0_col3" class="data row0 col3" >331</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a453d_row1_col0" class="data row1 col0" >Très bas</td>
#       <td id="T_a453d_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_a453d_row1_col2" class="data row1 col2" >4.76%</td>
#       <td id="T_a453d_row1_col3" class="data row1 col3" >147</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a453d_row2_col0" class="data row2 col0" >Bas-moyen</td>
#       <td id="T_a453d_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_a453d_row2_col2" class="data row2 col2" >6.65%</td>
#       <td id="T_a453d_row2_col3" class="data row2 col3" >842</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a453d_row3_col0" class="data row3 col0" >Bas-moyen</td>
#       <td id="T_a453d_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_a453d_row3_col2" class="data row3 col2" >7.02%</td>
#       <td id="T_a453d_row3_col3" class="data row3 col3" >541</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a453d_row4_col0" class="data row4 col0" >Moyen-haut</td>
#       <td id="T_a453d_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_a453d_row4_col2" class="data row4 col2" >21.52%</td>
#       <td id="T_a453d_row4_col3" class="data row4 col3" >948</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a453d_row5_col0" class="data row5 col0" >Moyen-haut</td>
#       <td id="T_a453d_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_a453d_row5_col2" class="data row5 col2" >19.47%</td>
#       <td id="T_a453d_row5_col3" class="data row5 col3" >647</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a453d_row6_col0" class="data row6 col0" >Très haut</td>
#       <td id="T_a453d_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_a453d_row6_col2" class="data row6 col2" >40.36%</td>
#       <td id="T_a453d_row6_col3" class="data row6 col3" >337</td>
#     </tr>
#     <tr>
#       <th id="T_a453d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a453d_row7_col0" class="data row7 col0" >Très haut</td>
#       <td id="T_a453d_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_a453d_row7_col2" class="data row7 col2" >39.34%</td>
#       <td id="T_a453d_row7_col3" class="data row7 col3" >272</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Interprétation
#
# Cette étape sert à distinguer :
# - une simple corrélation descriptive ;
# - d'un signal plus robuste qui reste visible quand on change de niveau d'analyse.
#
# Si l'effet de `shared interests` domine encore au niveau paire, alors l'argument produit devient plus crédible.

# %% [markdown]
# ## 8. Les participants évaluent-ils correctement leur propre valeur sur le marché du dating ?
#
# Le brief demande aussi si les individus savent correctement anticiper leur succès.
#
# On l'étudie avec deux angles :
# 1. leur capacité à anticiper le nombre de matches attendus ;
# 2. l'écart entre certaines **auto-évaluations** et les **notes effectivement reçues**.

# %%
# Construction d'un profil par participant :
# résumé de ses comportements, attentes et auto-évaluations sur toute la soirée
person = (
    df.groupby('iid')
      .agg(
          genre=('gender', 'first'),
          nb_dates=('dec', 'size'),
          expected_yes=('expnum', 'first'),         # nombre de oui attendus de la part des autres
          expected_matches=('match_es', 'first'),   # nombre de matches attendus
          actual_yes_received=('dec_o', 'sum'),     # oui réellement reçus
          actual_matches=('match', 'sum'),           # matches réellement obtenus
          # Auto-évaluations sur ses propres attributs
          self_attr=('attr3_1', 'first'),
          self_sinc=('sinc3_1', 'first'),
          self_intel=('intel3_1', 'first'),
          self_fun=('fun3_1', 'first'),
          self_amb=('amb3_1', 'first'),
          # Notes reçues en moyenne de la part des partenaires
          received_attr=('attr_o', 'mean'),
          received_sinc=('sinc_o', 'mean'),
          received_intel=('intel_o', 'mean'),
          received_fun=('fun_o', 'mean'),
          received_amb=('amb_o', 'mean'),
      )
      .reset_index()
)

# Corrélation entre matches attendus et matches réels
corr_match_est = person[['expected_matches', 'actual_matches']].dropna().corr().iloc[0, 1]

# Corrélation entre auto-évaluation et note reçue pour chaque attribut
self_vs_received = {}
for feat in ['attr', 'sinc', 'intel', 'fun', 'amb']:
    temp = person[[f'self_{feat}', f'received_{feat}']].dropna()
    self_vs_received[feat] = temp.corr().iloc[0, 1]

# Biais de prédiction par genre : se surestiment-ils ?
person['erreur_prediction'] = person['expected_matches'] - person['actual_matches']
biais_par_genre = (
    person.groupby('genre')[['expected_matches', 'actual_matches', 'erreur_prediction']]
          .mean()
          .rename(index={0: 'Femmes', 1: 'Hommes'})
)

# Tableau de synthèse des corrélations
display(pd.DataFrame({
    'Métrique': [
        'Corr(matches attendus, matches réels)',
        'Corr(self_attr, received_attr)',
        'Corr(self_fun, received_fun)',
        'Corr(self_intel, received_intel)',
        'Corr(self_sinc, received_sinc)',
        'Corr(self_amb, received_amb)',
    ],
    'Valeur': [
        corr_match_est,
        self_vs_received['attr'],
        self_vs_received['fun'],
        self_vs_received['intel'],
        self_vs_received['sinc'],
        self_vs_received['amb'],
    ]
}).style.format({'Valeur': '{:.3f}'}))

display(biais_par_genre.style.format('{:.2f}'))

# Nuage de points : matches attendus vs matches réels
plot_people = person[['expected_matches', 'actual_matches', 'genre']].dropna()
couleurs = plot_people['genre'].map({0: 'tab:blue', 1: 'tab:orange'})

plt.figure(figsize=(6, 6))
plt.scatter(plot_people['expected_matches'], plot_people['actual_matches'],
            alpha=0.35, c=couleurs)
maxv = max(plot_people['expected_matches'].max(), plot_people['actual_matches'].max())
plt.plot([0, maxv], [0, maxv], linestyle='--', label='Calibration parfaite')  # droite y=x
plt.xlabel("Matches attendus")
plt.ylabel("Matches réellement obtenus")
plt.title("Estimation des matches vs réalité")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_19860">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19860_level0_col0" class="col_heading level0 col0" >Métrique</th>
#       <th id="T_19860_level0_col1" class="col_heading level0 col1" >Valeur</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19860_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19860_row0_col0" class="data row0 col0" >Corr(matches attendus, matches réels)</td>
#       <td id="T_19860_row0_col1" class="data row0 col1" >0.429</td>
#     </tr>
#     <tr>
#       <th id="T_19860_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19860_row1_col0" class="data row1 col0" >Corr(self_attr, received_attr)</td>
#       <td id="T_19860_row1_col1" class="data row1 col1" >0.289</td>
#     </tr>
#     <tr>
#       <th id="T_19860_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19860_row2_col0" class="data row2 col0" >Corr(self_fun, received_fun)</td>
#       <td id="T_19860_row2_col1" class="data row2 col1" >0.280</td>
#     </tr>
#     <tr>
#       <th id="T_19860_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19860_row3_col0" class="data row3 col0" >Corr(self_intel, received_intel)</td>
#       <td id="T_19860_row3_col1" class="data row3 col1" >0.052</td>
#     </tr>
#     <tr>
#       <th id="T_19860_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19860_row4_col0" class="data row4 col0" >Corr(self_sinc, received_sinc)</td>
#       <td id="T_19860_row4_col1" class="data row4 col1" >-0.011</td>
#     </tr>
#     <tr>
#       <th id="T_19860_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19860_row5_col0" class="data row5 col0" >Corr(self_amb, received_amb)</td>
#       <td id="T_19860_row5_col1" class="data row5 col1" >0.158</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_e7c20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7c20_level0_col0" class="col_heading level0 col0" >expected_matches</th>
#       <th id="T_e7c20_level0_col1" class="col_heading level0 col1" >actual_matches</th>
#       <th id="T_e7c20_level0_col2" class="col_heading level0 col2" >erreur_prediction</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7c20_level0_row0" class="row_heading level0 row0" >Femmes</th>
#       <td id="T_e7c20_row0_col0" class="data row0 col0" >2.88</td>
#       <td id="T_e7c20_row0_col1" class="data row0 col1" >2.52</td>
#       <td id="T_e7c20_row0_col2" class="data row0 col2" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_e7c20_level0_row1" class="row_heading level0 row1" >Hommes</th>
#       <td id="T_e7c20_row1_col0" class="data row1 col0" >3.17</td>
#       <td id="T_e7c20_row1_col1" class="data row1 col1" >2.49</td>
#       <td id="T_e7c20_row1_col2" class="data row1 col2" >0.83</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Ce que montrent les données
#
# L'idée n'est pas de juger les participants, mais d'évaluer leur **calibration** :
#
# - sont-ils proches de la réalité ?
# - se surestiment-ils ?
# - ou sous-estiment-ils leur succès probable ?
#
# Le résultat attendu est donc nuancé : lucidité partielle ou biais systématique.

# %% [markdown]
# ## 8.1. Calibration : niveau d'optimisme et qualité d'auto-évaluation
#
# La corrélation donne un premier signal, mais elle ne suffit pas.
# On complète l'analyse avec une logique de **taux attendu** versus **taux réel**, afin de comparer proprement des participants qui n'ont pas tous rencontré le même nombre de personnes.

# %%
# Calibration en taux (plus comparable que les valeurs absolues car chaque participant
# n'a pas rencontré le même nombre de personnes dans la soirée)
calib = person[['genre', 'nb_dates', 'expected_matches', 'actual_matches']].dropna().copy()
calib = calib[calib['nb_dates'] > 0]

calib['taux_attendu'] = calib['expected_matches'] / calib['nb_dates']
calib['taux_reel']    = calib['actual_matches'] / calib['nb_dates']
calib['biais']        = calib['taux_attendu'] - calib['taux_reel']   # positif = surestimation
calib['erreur_abs']   = calib['biais'].abs()

# Résumé de la calibration par genre
calib_summary = (
    calib.groupby('genre')
         .agg(
             taux_attendu=('taux_attendu', 'mean'),
             taux_reel=('taux_reel', 'mean'),
             biais_moyen=('biais', 'mean'),
             mae=('erreur_abs', 'mean'),   # erreur absolue moyenne
             n=('biais', 'size')
         )
         .rename(index={0: 'Femmes', 1: 'Hommes'})
)
display(calib_summary.style.format({
    'taux_attendu': '{:.2%}',
    'taux_reel': '{:.2%}',
    'biais_moyen': '{:.2%}',
    'mae': '{:.2%}'
}))

# Nuage de points : taux de match attendu vs taux réel
# La droite en pointillés représente la calibration parfaite (attendu = réel)
plt.figure(figsize=(5, 5))
for g, label, marker in [(0, 'Femmes', 'o'), (1, 'Hommes', 's')]:
    sub = calib[calib['genre'] == g]
    plt.scatter(sub['taux_attendu'] * 100, sub['taux_reel'] * 100,
                alpha=0.6, label=label, marker=marker)
lim = max(calib['taux_attendu'].max(), calib['taux_reel'].max()) * 100
plt.plot([0, lim], [0, lim], linestyle='--', label='Calibration parfaite')
plt.xlabel("Taux de match attendu (%)")
plt.ylabel("Taux de match réel (%)")
plt.title("Calibration des anticipations de match")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_b39e3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b39e3_level0_col0" class="col_heading level0 col0" >taux_attendu</th>
#       <th id="T_b39e3_level0_col1" class="col_heading level0 col1" >taux_reel</th>
#       <th id="T_b39e3_level0_col2" class="col_heading level0 col2" >biais_moyen</th>
#       <th id="T_b39e3_level0_col3" class="col_heading level0 col3" >mae</th>
#       <th id="T_b39e3_level0_col4" class="col_heading level0 col4" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >genre</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b39e3_level0_row0" class="row_heading level0 row0" >Femmes</th>
#       <td id="T_b39e3_row0_col0" class="data row0 col0" >20.03%</td>
#       <td id="T_b39e3_row0_col1" class="data row0 col1" >16.49%</td>
#       <td id="T_b39e3_row0_col2" class="data row0 col2" >3.54%</td>
#       <td id="T_b39e3_row0_col3" class="data row0 col3" >11.64%</td>
#       <td id="T_b39e3_row0_col4" class="data row0 col4" >240</td>
#     </tr>
#     <tr>
#       <th id="T_b39e3_level0_row1" class="row_heading level0 row1" >Hommes</th>
#       <td id="T_b39e3_row1_col0" class="data row1 col0" >23.18%</td>
#       <td id="T_b39e3_row1_col1" class="data row1 col1" >16.02%</td>
#       <td id="T_b39e3_row1_col2" class="data row1 col2" >7.15%</td>
#       <td id="T_b39e3_row1_col3" class="data row1 col3" >12.84%</td>
#       <td id="T_b39e3_row1_col4" class="data row1 col4" >239</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Interprétation
#
# Cette lecture permet de distinguer deux idées :
# - les participants disposent d'une **intuition partielle** de leur succès potentiel ;
# - mais cette intuition reste **imparfaitement calibrée**, avec une tendance moyenne à la surestimation.
#
# C'est une réponse plus précise que le simple constat d'une corrélation positive.

# %% [markdown]
# ## 9. Effet de l'ordre de passage dans la soirée
#
# Le brief suggère de tester si être vu **tôt** ou **tard** dans la soirée peut influencer l'issue d'un rendez-vous.
#
# Pour éviter une lecture trompeuse, on ne compare pas seulement l'ordre brut.
# On construit aussi un **ordre relatif**, afin de rendre comparables des soirées qui n'ont pas le même nombre de rounds.

# %%
# Nettoyage : on conserve uniquement les soirées avec au moins 2 rounds
# pour pouvoir calculer un ordre relatif significatif
order_tmp = df[['order', 'round', 'dec', 'match']].dropna().copy()
order_tmp = order_tmp[order_tmp['round'] > 1]

# Ordre relatif : position du date dans la soirée, normalisée entre 0 (début) et 1 (fin)
# Cela permet de comparer des soirées de longueurs différentes
order_tmp['ordre_relatif'] = (order_tmp['order'] - 1) / (order_tmp['round'] - 1)
order_tmp['tranche'] = pd.cut(
    order_tmp['ordre_relatif'],
    bins=[-0.01, 0.33, 0.66, 1.0],
    labels=['Début', 'Milieu', 'Fin']
)

# Taux par tranche de la soirée
order_summary = order_tmp.groupby('tranche', observed=False).agg(
    yes_rate=('dec', 'mean'),
    match_rate=('match', 'mean'),
    n=('match', 'size')
)

display(order_summary.style.format({'yes_rate': '{:.2%}', 'match_rate': '{:.2%}'}))

# Graphique
x = np.arange(len(order_summary.index))
width = 0.35

plt.figure(figsize=(8, 4))
plt.bar(x - width / 2, order_summary['yes_rate'] * 100, width, label='Yes rate')
plt.bar(x + width / 2, order_summary['match_rate'] * 100, width, label='Match rate')
plt.xticks(x, order_summary.index)
plt.ylabel("Pourcentage")
plt.title("Effet de l'ordre relatif du date dans la soirée")
plt.legend()
plt.tight_layout()
plt.show()

# Corrélations brutes pour compléter la lecture
print("Corr(ordre brut, dec)            =", round(order_tmp['order'].corr(order_tmp['dec']), 3))
print("Corr(ordre brut, match)          =", round(order_tmp['order'].corr(order_tmp['match']), 3))
print("Corr(ordre relatif, match)       =", round(order_tmp['ordre_relatif'].corr(order_tmp['match']), 3))
# Out:
# <style type="text/css">
# </style>
# <table id="T_52493">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52493_level0_col0" class="col_heading level0 col0" >yes_rate</th>
#       <th id="T_52493_level0_col1" class="col_heading level0 col1" >match_rate</th>
#       <th id="T_52493_level0_col2" class="col_heading level0 col2" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tranche</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52493_level0_row0" class="row_heading level0 row0" >Début</th>
#       <td id="T_52493_row0_col0" class="data row0 col0" >42.57%</td>
#       <td id="T_52493_row0_col1" class="data row0 col1" >17.22%</td>
#       <td id="T_52493_row0_col2" class="data row0 col2" >2765</td>
#     </tr>
#     <tr>
#       <th id="T_52493_level0_row1" class="row_heading level0 row1" >Milieu</th>
#       <td id="T_52493_row1_col0" class="data row1 col0" >43.05%</td>
#       <td id="T_52493_row1_col1" class="data row1 col1" >16.67%</td>
#       <td id="T_52493_row1_col2" class="data row1 col2" >2639</td>
#     </tr>
#     <tr>
#       <th id="T_52493_level0_row2" class="row_heading level0 row2" >Fin</th>
#       <td id="T_52493_row2_col0" class="data row2 col0" >40.52%</td>
#       <td id="T_52493_row2_col1" class="data row2 col1" >15.60%</td>
#       <td id="T_52493_row2_col2" class="data row2 col2" >2974</td>
#     </tr>
#   </tbody>
# </table>
# Corr(ordre brut, dec)            = -0.032
# Corr(ordre brut, match)          = -0.039
# Corr(ordre relatif, match)       = -0.02

# %% [markdown]
# ### Résultat
#
# Si un effet existe, il doit être interprété comme un **effet de contexte** :
# fatigue, saturation, baisse d'attention en fin de soirée, etc.
#
# La question importante est donc moins de savoir si l'effet existe que de mesurer **son poids relatif** par rapport aux signaux majeurs du projet.

# %% [markdown]
# ## 10. Quelques variables de contexte disponibles avant la rencontre
#
# Pour compléter l'analyse, on examine des variables potentiellement mobilisables **avant même l'échange**, comme l'écart d'âge.
#
# L'objectif est de comparer leur apport à celui des variables construites pendant l'interaction.

# %%
# Calcul de l'écart d'âge absolu entre les deux participants du date
df['age_gap'] = (df['age'] - df['age_o']).abs()

agegap = df[['age_gap', 'dec', 'match']].dropna().copy()

# Découpage en 4 catégories d'écart d'âge
agegap['tranche_age'] = pd.cut(
    agegap['age_gap'],
    bins=[-0.1, 1, 3, 5, 20],
    labels=['0-1 an', '2-3 ans', '4-5 ans', '6 ans et +']
)

agegap_summary = agegap.groupby('tranche_age', observed=False).agg(
    yes_rate=('dec', 'mean'),
    match_rate=('match', 'mean'),
    n=('match', 'size')
)

display(agegap_summary.style.format({'yes_rate': '{:.2%}', 'match_rate': '{:.2%}'}))

plt.figure(figsize=(7, 4))
plt.bar(agegap_summary.index.astype(str), agegap_summary['match_rate'] * 100)
plt.ylabel("Taux de match (%)")
plt.xlabel("Écart d'âge")
plt.title("Taux de match selon l'écart d'âge entre les participants")
plt.tight_layout()
plt.show()
# Out:
# <style type="text/css">
# </style>
# <table id="T_9f8ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f8ad_level0_col0" class="col_heading level0 col0" >yes_rate</th>
#       <th id="T_9f8ad_level0_col1" class="col_heading level0 col1" >match_rate</th>
#       <th id="T_9f8ad_level0_col2" class="col_heading level0 col2" >n</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tranche_age</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f8ad_level0_row0" class="row_heading level0 row0" >0-1 an</th>
#       <td id="T_9f8ad_row0_col0" class="data row0 col0" >44.29%</td>
#       <td id="T_9f8ad_row0_col1" class="data row0 col1" >18.87%</td>
#       <td id="T_9f8ad_row0_col2" class="data row0 col2" >2226</td>
#     </tr>
#     <tr>
#       <th id="T_9f8ad_level0_row1" class="row_heading level0 row1" >2-3 ans</th>
#       <td id="T_9f8ad_row1_col0" class="data row1 col0" >43.02%</td>
#       <td id="T_9f8ad_row1_col1" class="data row1 col1" >17.79%</td>
#       <td id="T_9f8ad_row1_col2" class="data row1 col2" >2406</td>
#     </tr>
#     <tr>
#       <th id="T_9f8ad_level0_row2" class="row_heading level0 row2" >4-5 ans</th>
#       <td id="T_9f8ad_row2_col0" class="data row2 col0" >41.49%</td>
#       <td id="T_9f8ad_row2_col1" class="data row2 col1" >15.62%</td>
#       <td id="T_9f8ad_row2_col2" class="data row2 col2" >1728</td>
#     </tr>
#     <tr>
#       <th id="T_9f8ad_level0_row3" class="row_heading level0 row3" >6 ans et +</th>
#       <td id="T_9f8ad_row3_col0" class="data row3 col0" >38.50%</td>
#       <td id="T_9f8ad_row3_col1" class="data row3 col1" >12.50%</td>
#       <td id="T_9f8ad_row3_col2" class="data row3 col2" >1808</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Lecture
#
# L'écart d'âge n'est pas présenté ici comme un levier central.
# Il s'agit plutôt d'un signal de contexte susceptible d'améliorer marginalement une logique de matching ex ante.

# %% [markdown]
# ## 11. Bonus de modélisation : profil seul vs impressions du rendez-vous
#
# Le sujet n'exige pas de machine learning, mais ce bonus apporte un éclairage utile au storytelling final.
#
# Trois blocs sont comparés :
# - **modèle A** : variables de profil / contexte avant la rencontre ;
# - **modèle B** : impressions du rendez-vous ;
# - **modèle C** : combinaison des deux.
#
# ### Choix méthodologique
# Pour limiter un optimisme artificiel, l'évaluation est faite via des splits **par participant** (`iid`) et non via un simple split aléatoire par ligne.

# %%
def evaluer_modele(donnees, cible, variables, col_groupe='iid', n_splits=5, random_state=42):
    """
    Entraîne et évalue une régression logistique avec validation croisée par participant.
    
    Le split est fait par iid (participant) et non par ligne pour éviter la fuite
    de données liée au fait qu'un même participant apparaît plusieurs fois dans le dataset.
    
    Retourne : (résultats par fold, pipeline entraîné, X_test, y_test du dernier fold)
    """
    travail = donnees[variables + [cible, col_groupe]].copy()
    X = travail[variables]
    y = travail[cible].astype(int)
    groupes = travail[col_groupe]

    # GroupShuffleSplit garantit qu'un même participant ne se retrouve pas
    # à la fois dans le train et dans le test
    splitter = GroupShuffleSplit(n_splits=n_splits, test_size=0.25, random_state=random_state)

    resultats = []
    pipeline_final = None
    X_test_final = None
    y_test_final = None

    for fold, (idx_train, idx_test) in enumerate(splitter.split(X, y, groupes), start=1):
        # Pipeline : imputation → normalisation → régression logistique
        pipe = Pipeline([
            ('imputation', SimpleImputer(strategy='median')),   # remplace les NaN par la médiane
            ('normalisation', StandardScaler()),                  # centre et réduit les variables
            ('modele', LogisticRegression(max_iter=1000, class_weight='balanced'))
        ])

        X_train, X_test = X.iloc[idx_train], X.iloc[idx_test]
        y_train, y_test = y.iloc[idx_train], y.iloc[idx_test]

        pipe.fit(X_train, y_train)
        pred  = pipe.predict(X_test)
        proba = pipe.predict_proba(X_test)[:, 1]

        resultats.append({
            'fold': fold,
            'roc_auc': roc_auc_score(y_test, proba),
            'accuracy': accuracy_score(y_test, pred),
            'f1': f1_score(y_test, pred),
        })

        pipeline_final = pipe
        X_test_final   = X_test
        y_test_final   = y_test

    return pd.DataFrame(resultats), pipeline_final, X_test_final, y_test_final


# --- Définition des trois familles de variables ---

# Modèle A : variables disponibles AVANT la rencontre (profil + contexte)
vars_profil = [c for c in [
    'gender', 'age', 'age_o', 'samerace', 'order', 'int_corr', 'imprace', 'imprelig',
    'date', 'go_out', 'exphappy', 'expnum',
    'sports', 'tvsports', 'exercise', 'dining', 'museums', 'art', 'hiking',
    'gaming', 'clubbing', 'reading', 'tv', 'theater', 'movies', 'concerts',
    'music', 'shopping', 'yoga'
] if c in df.columns]

# Modèle B : impressions recueillies PENDANT le rendez-vous
vars_date = [c for c in ['attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob']
             if c in df.columns]

# Modèle C : combinaison des deux
vars_combined = vars_profil + vars_date

# --- Entraînement et évaluation des trois modèles ---
cv_profil,    _,               _,            _            = evaluer_modele(df, 'match', vars_profil)
cv_date,      _,               _,            _            = evaluer_modele(df, 'match', vars_date)
cv_combined,  pipe_combined,   X_test_final, y_test_final = evaluer_modele(df, 'match', vars_combined)

# Comparaison des performances
resultats_modeles = pd.DataFrame([
    {
        'modele': 'Profil / contexte',
        'roc_auc_moy': cv_profil['roc_auc'].mean(),
        'roc_auc_std': cv_profil['roc_auc'].std(),
        'accuracy_moy': cv_profil['accuracy'].mean(),
        'f1_moy': cv_profil['f1'].mean(),
    },
    {
        'modele': 'Impressions du date',
        'roc_auc_moy': cv_date['roc_auc'].mean(),
        'roc_auc_std': cv_date['roc_auc'].std(),
        'accuracy_moy': cv_date['accuracy'].mean(),
        'f1_moy': cv_date['f1'].mean(),
    },
    {
        'modele': 'Profil + date',
        'roc_auc_moy': cv_combined['roc_auc'].mean(),
        'roc_auc_std': cv_combined['roc_auc'].std(),
        'accuracy_moy': cv_combined['accuracy'].mean(),
        'f1_moy': cv_combined['f1'].mean(),
    },
]).sort_values('roc_auc_moy', ascending=False)

display(resultats_modeles.style.format({
    'roc_auc_moy': '{:.3f}', 'roc_auc_std': '{:.3f}',
    'accuracy_moy': '{:.3f}', 'f1_moy': '{:.3f}'
}))

plt.figure(figsize=(7, 4))
plt.bar(resultats_modeles['modele'], resultats_modeles['roc_auc_moy'])
plt.ylabel("ROC-AUC moyen")
plt.title("Pouvoir prédictif comparé des familles de variables")
plt.xticks(rotation=15, ha='right')
plt.tight_layout()
plt.show()

# Importance des variables par permutation (sur le dernier fold du modèle combiné)
perm = permutation_importance(
    pipe_combined, X_test_final, y_test_final,
    n_repeats=10, random_state=42, scoring='roc_auc'
)

importance_df = pd.DataFrame({
    'variable': vars_combined,
    'importance': perm.importances_mean
}).sort_values('importance', ascending=False)

display(importance_df.head(12).style.format({'importance': '{:.4f}'}))
# Out:
# <style type="text/css">
# </style>
# <table id="T_12102">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12102_level0_col0" class="col_heading level0 col0" >modele</th>
#       <th id="T_12102_level0_col1" class="col_heading level0 col1" >roc_auc_moy</th>
#       <th id="T_12102_level0_col2" class="col_heading level0 col2" >roc_auc_std</th>
#       <th id="T_12102_level0_col3" class="col_heading level0 col3" >accuracy_moy</th>
#       <th id="T_12102_level0_col4" class="col_heading level0 col4" >f1_moy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12102_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_12102_row0_col0" class="data row0 col0" >Impressions du date</td>
#       <td id="T_12102_row0_col1" class="data row0 col1" >0.776</td>
#       <td id="T_12102_row0_col2" class="data row0 col2" >0.009</td>
#       <td id="T_12102_row0_col3" class="data row0 col3" >0.694</td>
#       <td id="T_12102_row0_col4" class="data row0 col4" >0.438</td>
#     </tr>
#     <tr>
#       <th id="T_12102_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_12102_row1_col0" class="data row1 col0" >Profil + date</td>
#       <td id="T_12102_row1_col1" class="data row1 col1" >0.774</td>
#       <td id="T_12102_row1_col2" class="data row1 col2" >0.006</td>
#       <td id="T_12102_row1_col3" class="data row1 col3" >0.706</td>
#       <td id="T_12102_row1_col4" class="data row1 col4" >0.441</td>
#     </tr>
#     <tr>
#       <th id="T_12102_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_12102_row2_col0" class="data row2 col0" >Profil / contexte</td>
#       <td id="T_12102_row2_col1" class="data row2 col1" >0.565</td>
#       <td id="T_12102_row2_col2" class="data row2 col2" >0.008</td>
#       <td id="T_12102_row2_col3" class="data row2 col3" >0.564</td>
#       <td id="T_12102_row2_col4" class="data row2 col4" >0.277</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_dcb5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcb5e_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_dcb5e_level0_col1" class="col_heading level0 col1" >importance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcb5e_level0_row0" class="row_heading level0 row0" >35</th>
#       <td id="T_dcb5e_row0_col0" class="data row0 col0" >like</td>
#       <td id="T_dcb5e_row0_col1" class="data row0 col1" >0.0471</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row1" class="row_heading level0 row1" >29</th>
#       <td id="T_dcb5e_row1_col0" class="data row1 col0" >attr</td>
#       <td id="T_dcb5e_row1_col1" class="data row1 col1" >0.0294</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row2" class="row_heading level0 row2" >36</th>
#       <td id="T_dcb5e_row2_col0" class="data row2 col0" >prob</td>
#       <td id="T_dcb5e_row2_col1" class="data row2 col1" >0.0273</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row3" class="row_heading level0 row3" >32</th>
#       <td id="T_dcb5e_row3_col0" class="data row3 col0" >fun</td>
#       <td id="T_dcb5e_row3_col1" class="data row3 col1" >0.0238</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_dcb5e_row4_col0" class="data row4 col0" >shar</td>
#       <td id="T_dcb5e_row4_col1" class="data row4 col1" >0.0082</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row5" class="row_heading level0 row5" >33</th>
#       <td id="T_dcb5e_row5_col0" class="data row5 col0" >amb</td>
#       <td id="T_dcb5e_row5_col1" class="data row5 col1" >0.0072</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row6" class="row_heading level0 row6" >20</th>
#       <td id="T_dcb5e_row6_col0" class="data row6 col0" >clubbing</td>
#       <td id="T_dcb5e_row6_col1" class="data row6 col1" >0.0054</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row7" class="row_heading level0 row7" >31</th>
#       <td id="T_dcb5e_row7_col0" class="data row7 col0" >intel</td>
#       <td id="T_dcb5e_row7_col1" class="data row7 col1" >0.0041</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row8" class="row_heading level0 row8" >17</th>
#       <td id="T_dcb5e_row8_col0" class="data row8 col0" >art</td>
#       <td id="T_dcb5e_row8_col1" class="data row8 col1" >0.0040</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row9" class="row_heading level0 row9" >16</th>
#       <td id="T_dcb5e_row9_col0" class="data row9 col0" >museums</td>
#       <td id="T_dcb5e_row9_col1" class="data row9 col1" >0.0028</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row10" class="row_heading level0 row10" >27</th>
#       <td id="T_dcb5e_row10_col0" class="data row10 col0" >shopping</td>
#       <td id="T_dcb5e_row10_col1" class="data row10 col1" >0.0025</td>
#     </tr>
#     <tr>
#       <th id="T_dcb5e_level0_row11" class="row_heading level0 row11" >9</th>
#       <td id="T_dcb5e_row11_col0" class="data row11 col0" >go_out</td>
#       <td id="T_dcb5e_row11_col1" class="data row11 col1" >0.0025</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Enseignement du bonus
#
# Ce bonus ne sert pas à produire un modèle industrialisable.
# Il sert à répondre, de manière quantitative, à une question simple :
#
# > le résultat final est-il mieux expliqué par le **profil** ou par l'**interaction vécue** ?
#
# C'est ce qui lui donne sa valeur dans le cadre d'un projet exploratoire.

# %% [markdown]
# ## 12. Réponse synthétique à la problématique produit
#
# À ce stade, l'analyse permet de répondre directement à la question initiale.
#
# Ce qui semble faire monter la probabilité d'un second rendez-vous n'est pas seulement la similarité de profil, mais surtout la qualité de l'interaction :
# - une bonne impression globale ;
# - une rencontre perçue comme agréable ;
# - des intérêts partagés ;
# - et une attractivité perçue suffisante.

# %% [markdown]
# ## 13. Recommandations business
#
# Les résultats suggèrent plusieurs implications pour une application de rencontre :
#
# 1. **ne pas surinvestir les variables démographiques brutes** ;
# 2. **mieux valoriser les signaux de compatibilité concrète** ;
# 3. **traiter les variables de profil comme des priors faibles** ;
# 4. **construire des expériences qui favorisent la qualité d'interaction** ;
# 5. **considérer les effets de séquencement comme secondaires**.

# %% [markdown]
# ## 13.1. Scorecard de priorisation des signaux
#
# Le tableau suivant résume les variables ou familles de variables selon trois dimensions :
# - la force apparente du signal ;
# - son caractère potentiellement actionnable ;
# - la prudence d'interprétation à conserver.
#
# L'objectif est de conclure sur une vision **opérationnelle** et non uniquement descriptive.

# %%
# Tableau de priorisation des signaux pour une logique produit
# Résume pour chaque signal : sa force, son actionnabilité et la prudence d'interprétation
scorecard = pd.DataFrame([
    ['Attractiveness perçue pendant le date', 'Fort',           'Oui',           'Signal important, mais pas suffisant seul'],
    ['Fun / qualité de l\'échange',           'Fort',           'Oui',           'Très lié aux issues positives'],
    ['Intérêts partagés perçus',              'Fort',           'Oui',           'Plus utile que la simple similarité démographique'],
    ['Même race',                             'Faible',         'Avec prudence', 'Effet faible face aux signaux relationnels'],
    ['Ordre du date dans la soirée',          'Faible à modéré','Secondaire',    'Effet cohérent mais non dominant'],
    ['Variables de profil seules',            'Faible',         'Limité',        'Pouvoir explicatif inférieur aux signaux d\'interaction'],
    ['Auto-prédiction du succès',             'Imparfait',      'Non directement','Les participants sont partiellement mais mal calibrés']
], columns=['Signal', 'Niveau d\'évidence', 'Action produit ?', 'Lecture business'])

display(scorecard)
# Out:
#                                   Signal Niveau d'évidence Action produit ?                                   Lecture business
# 0  Attractiveness perçue pendant le date              Fort              Oui          Signal important, mais pas suffisant seul
# 1             Fun / qualité de l'échange              Fort              Oui                      Très lié aux issues positives
# 2               Intérêts partagés perçus              Fort              Oui  Plus utile que la simple similarité démographique
# 3                              Même race            Faible    Avec prudence         Effet faible face aux signaux relationnels
# 4           Ordre du date dans la soirée   Faible à modéré       Secondaire                   Effet cohérent mais non dominant
# 5             Variables de profil seules            Faible           Limité  Pouvoir explicatif inférieur aux signaux d'int...
# 6              Auto-prédiction du succès         Imparfait  Non directement  Les participants sont partiellement mais mal c...

# %% [markdown]
# ## 14. Limites et précautions d'interprétation
#
# Comme tout projet sérieux, cette analyse doit expliciter ses limites :
#
# 1. le dataset provient d'un **speed dating expérimental** datant du début des années 2000 ;
# 2. plusieurs variables fortes sont recueillies **après interaction** ;
# 3. les observations ne sont pas totalement indépendantes ;
# 4. certaines colonnes comportent beaucoup de valeurs manquantes ;
# 5. les questionnaires n'utilisent pas toujours les mêmes échelles selon les vagues.
#
# Ces limites ne remettent pas en cause l'intérêt du projet, mais elles encadrent la portée des conclusions.

# %% [markdown]
# # Conclusion
#
# L'analyse met en évidence une idée simple mais importante : le succès d'une rencontre ne se résume pas à la proximité de profil.
#
# Les signaux les plus convaincants sont surtout :
# - l'appréciation globale de la rencontre ;
# - le **fun** ;
# - les **intérêts partagés** ;
# - et l'attractivité perçue.
#
# À l'inverse, les variables de profil seules expliquent relativement peu le résultat final.
#
# Dans une logique produit, cela plaide pour des systèmes de matching qui cherchent moins à rapprocher des profils simplement « semblables » qu'à favoriser les combinaisons de profils susceptibles de générer une interaction fluide, agréable et réciproque.
